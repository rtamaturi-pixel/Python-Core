# %% [markdown]
# # Strings:
# - String is a **sequence of Characters**
# - Written with single quotes / Double Quotes / triple quotes
# - Triple Quotes are used for writing multi line strings
# - String can be treated as an **Array**
# - String characters can be accessed by referring to their **Index** values
# - Strings are **immutable**

# %%
a = 'x'

# %%
type(a)
# Out:
# str

# %%
a = 'python'
b = "Programming"
c = '''Python is good 
programming language'''

# %%
print(type(a),type(b),type(c))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %% [markdown]
# # Array:

# %% [markdown]
# - Array is a **collection of homogeneous** data elements
# - Array are with same Data Types. must be of the same type (e.g., all integers, all floats).
# - Mutable :You can change, add, or remove elements after creation.

# %%
a = 'p'

# %%
b = 'y'

# %%
c = 't'

# %%
a = 'python'

# %% [markdown]
# ### Accessing String Characters :
# - String Characters can be accessed by referring to their positive / negative Index
# - In python , Indexing Starts with Zero ( 0 )
# - 0,1,2,3.... and from reverse it starts with -1,-2,-3,....

# %%
a = 'Programming'

# %%
a[0]
# Out:
# 'P'

# %%
a[1]
# Out:
# 'r'

# %%
a[-1]
# Out:
# 'g'

# %%
a[-10]
# Out:
# 'r'

# %% [markdown]
# ### String Slicing : Part of a String

# %%
MAX = 89
MAX = 44
print(MAX) #no specific constants in Python, Variable can be re assigned in anytime.
# Out:
# 44

# %%
a = 'Programming'

# %% [raw]
# String Slicing:
#
# Accessing a Part / Portion of String By Referring To Range Of Indices.
#
# syntax:
#     string [start_index : End_index]
#
# Note: End index is not included.
#
# example:
# a = 'Programming'
# a[2:5] ---> 5 is not Included. i.e(5-1)

# %%
a = 'Programming'

# %%
a[2:5]      #sclicing from 2nd position to 5th (5-1 = 4th/actual)
# Out:
# 'ogr'

# %%
print(a[1:4])
# Out:
# rog

# %%
a[3:8]
# Out:
# 'gramm'

# %%
a[4:] # not mention end string, so that it will take to the End-of-String
# Out:
# 'ramming'

# %%
a[-3]
# Out:
# 'i'

# %%
a[-3:-6]
# Out:
# ''

# %%
a[:6] # and same as a[0:6]
# Out:
# 'Progra'

# %%
a[:]
# Out:
# 'Programming'

# %%
a[-5:]
# Out:
# 'mmin'

# %%
a[:-5]
# Out:
# 'progra'

# %% [markdown]
# ### STEP SKIP (STEP SIZE STRINGS):

# %%
a = 'Programming'

# %%
a[0:6:2] # 2 is the difference between 0 and 2, in P and O for programming.
# Out:
# 'Por'

# %%
a[::3] # till End- Index
# Out:
# 'Pgmn'

# %%
a[4::3]
# Out:
# 'rmg'

# %%
print(a[0:2],a[3:5])
# Out:
# Pr gr

# %%
a[::-1]   # right to left reverse order complete
# Out:
# 'gnimmargorP'

# %%
# access all character except last one
a = "Programming"


a[0:-1]
# Out:
# 'Programmin'

# %%
# Access all character except Last 2 character.
a[0:-2]
# Out:
# 'Programmi'

# %%
# access last two characters
a[-2:]
# Out:
# 'ng'

# %% [markdown]
# # String Methods: " .method() "

# %%
a = 'programming'

# %% [markdown]
# ### Upper() :-

# %%
print(a.upper())
# Out:
# PROGRAMMING

# %%
print(help(str.upper))
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.
#
# None

# %% [markdown]
# ### Lower() :-

# %%
print(help(str.lower))
# Out:
# Help on method_descriptor:
#
# lower(self, /) unbound builtins.str method
#     Return a copy of the string converted to lowercase.
#
# None

# %%
a = 'PROGRAMMING'
a.lower()
# Out:
# 'programming'

# %%
a.casefold()
# Out:
# 'programming'

# %% [markdown]
# ### Capatalize() :-

# %%
print(help(str.capitalize))
# Out:
# Help on method_descriptor:
#
# capitalize(self, /) unbound builtins.str method
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.
#
# None

# %%
a = 'programming'
a.capitalize()
# Out:
# 'Programming'

# %%
a = 'PYthon PrOGRAmming LANguage'
a.capitalize()
# Out:
# 'Python programming language'

# %% [markdown]
# ### Title() :-

# %%
print(help(str.title))
# Out:
# Help on method_descriptor:
#
# title(self, /) unbound builtins.str method
#     Return a version of the string where each word is titlecased.
#
#     More specifically, words start with uppercased characters and all remaining
#     cased characters have lower case.
#
# None

# %%
a = 'PYthon PrOGRAmming LANguage'
a.title()
# Out:
# 'Python Programming Language'

# %% [markdown]
# ### Startswith() :-

# %%
help(str.startswith)   # checks the Prefix - start characters
# Out:
# Help on method_descriptor:
#
# startswith(self, prefix[, start[, end]], /) unbound builtins.str method
#     Return True if the string starts with the specified prefix, False otherwise.
#
#     prefix
#       A string or a tuple of strings to try.
#     start
#       Optional start position. Default: start of the string.
#     end
#       Optional stop position. Default: end of the string.

# %%
a = 'programming'

a.startswith('p')
# Out:
# True

# %%
a.startswith('x')
# Out:
# False

# %%
a = 'Python Programming'
a.startswith('Python')   # it is case sensitive.
# Out:
# True

# %% [markdown]
# ### Endswith() :-

# %%
print(help(str.endswith))    # checks the sufix- end characters.
# Out:
# Help on method_descriptor:
#
# endswith(self, suffix[, start[, end]], /) unbound builtins.str method
#     Return True if the string ends with the specified suffix, False otherwise.
#
#     suffix
#       A string or a tuple of strings to try.
#     start
#       Optional start position. Default: start of the string.
#     end
#       Optional stop position. Default: end of the string.
#
# None

# %%
a.endswith('ing')
# Out:
# True

# %%
a.endswith('x')
# Out:
# False

# %%
a.endswith('Programming')
# Out:
# True

# %%
a.startswith('t',2) # 2 is the position to check for t in string.
# Out:
# True

# %%
a = "Data science with python"
a.startswith('science',5,12)
# Out:
# True

# %%
a.startswith(('Data','info', 'ML'))  # any one true in tuple of strings result in 'True'
# Out:
# True

# %% [markdown]
# ### Count() :-

# %%
print(help(str.count))
# Out:
# Help on method_descriptor:
#
# count(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#
# None

# %%
a = 'programming'
a.count('m')  # count the no of non overlapping occurance in string
# Out:
# 2

# %%
len(a) # counts total characterstics in a Data
# Out:
# 11

# %% [markdown]
# ### Index() :- writes the lowest index of a sub-string

# %%
print(help(str.index))
# Out:
# Help on method_descriptor:
#
# index(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.
#
# None

# %%
a = 'programming' # there are 2 r's in the programming but it give the position of lowest index (lowest r in 1st position)
a.index('r')
# Out:
# 1

# %%
a.index('g')
# Out:
# 3

# %%
a.index('p')
# Out:
# 0

# %%
x ='python programming' # the programming starts with the 7th postion
x.index('programming')
# Out:
# 7

# %%
x.index('python')
# Out:
# 0

# %% [markdown]
# ### rindex() :- writes Highest index in a substring.

# %%
print(help(str.rindex))
# Out:
# Help on method_descriptor:
#
# rindex(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the highest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.
#
# None

# %%
a
# Out:
# 'programming'

# %%
a.rindex('m')  # m is in both 6th and 7th location. so the highest is 7th one.
# Out:
# 7

# %%
a.rindex('g')
# Out:
# 10

# %%
a.rindex('p')
# Out:
# 0

# %%
a.rindex('r')
# Out:
# 4

# %% [markdown]
# ### find() :- Return the lowest index in S where substring sub is found, (or) Return -1 on failure. but not an error!

# %%
print(help(str.find))
# Out:
# Help on method_descriptor:
#
# find(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Return -1 on failure.
#
# None

# %%
a.find('m')
# Out:
# 6

# %% [markdown]
# #### the find method return '-1' in the failure, but index method return to the 'error'. so its always prefereable to use the find method.

# %% [markdown]
# ### rfind() :- return the highest index in the string and return -1 on failure.

# %%
a
# Out:
# 'programming'

# %%
a.rfind('m')
# Out:
# 7

# %%
a.rfind('r')
# Out:
# 4

# %%
a.rfind('g')
# Out:
# 10

# %%
a.rfind('z')
# Out:
# -1

# %% [markdown]
# ### Split() :_

# %%
print(help(str.split))
# Out:
# Help on method_descriptor:
#
# split(self, /, sep=None, maxsplit=-1) unbound builtins.str method
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \n \r \t \f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits.
#         -1 (the default value) means no limit.
#
#     Splitting starts at the front of the string and works to the end.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.
#
# None

# %%
a = 'python is a good programming language'

# %%
a.split()
# Out:
# ['python', 'is', 'a', 'good', 'programming', 'language']

# %%
b = 'Iam Doing Good'
b.split()
# Out:
# ['Iam', 'Doing', 'Good']

# %%
c = 'Python@popular@learn@use@good'
c.split('@')
# Out:
# ['Python', 'popular', 'learn', 'use', 'good']

# %%
d = 'Python/programming/langugag/software'
d.split('/')
# Out:
# ['Python', 'programming', 'langugag', 'software']

# %%
a = 'programming'  # if the seperetor is at the beginning or the ending of the string, it return empty sub string. ('')
a.split('p')
# Out:
# ['', 'rogramming']

# %%
a.split('g')
# Out:
# ['pro', 'rammin', '']

# %%
a.split('m')  # returned till m, but the other half is also starting with the seperater m so it returned empty value.
# Out:
# ['progra', '', 'ing']

# %%
a = 'python programming' # the second P is not the beginning it has space before it, so no space quotation before.
a.split('p')
# Out:
# ['', 'ython ', 'rogramming']

# %% [markdown]
# ### Join() :-  Concatenate any number of strings.

# %%
print(help(str.join))
# Out:
# Help on method_descriptor:
#
# join(self, iterable, /) unbound builtins.str method
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
#
# None

# %%
a = ['python', 'is', 'a', 'good', 'programming', 'language']  # [] written inside the square brackets are called as list, it should be seperated with ','

# %%
' '.join(a)
# Out:
# 'python is a good programming language'

# %%
'/'.join(a)
# Out:
# 'python/is/a/good/programming/language'

# %%
','.join(a)
# Out:
# 'python,is,a,good,programming,language'

# %%
''.join(a) # if you dont mention the joiner, it will join whole thing togehter.
# Out:
# 'pythonisagoodprogramminglanguage'

# %% [markdown]
# ### format() :- it is used to Substitute a string in string. subsitute positon should be with '{}'

# %%
print(help(str.format))
# Out:
# Help on method_descriptor:
#
# format(self, /, *args, **kwargs) unbound builtins.str method
#     Return a formatted version of the string, using substitutions from args and kwargs.
#     The substitutions are identified by braces ('{' and '}').
#
# None

# %%
a = 'my name is {}, my age is {}'
a.format('Rupesh', 26)
# Out:
# 'my name is Rupesh, my age is 26'

# %%
a.format('vikas',34)
# Out:
# 'my name is vikas, my age is 34'

# %%
a.format('shiva',44)
# Out:
# 'my name is shiva, my age is 44'

# %%
a = 'my name is: {0}, my age is: {1}, My country is: {2}, My state is: {3}'
a.format('Rupesh',26,'India','AP')
# Out:
# 'my name is: Rupesh, my age is: 26, My country is: India, My state is: AP'

# %%
print(a.format('Rupesh',26,'India','AP'))
# Out:
# my name is: Rupesh, my age is: 26, My country is: India, My state is: AP

# %% [markdown]
# #### format with Keywords: {keyword}

# %%
a = 'my name is {name}, My age is {age}, My country is {country}, My state is {state}'
a.format(age='26', name='Rupesh', country='India', state='AP')
# Out:
# 'my name is Rupesh, My age is 26, My country is India, My state is AP'

# %%
a = 45
b = 33
c = a + b
d = a - b

# %%
print("the result of addition is {}, The result of substraction is {}".format(c,d))
# Out:
# the result of addition is 78, The result of substraction is 12

# %%
print("the result of addition is",c,"The substraction of result is",d)
# Out:
# the result of addition is 78 The substraction of result is 12

# %% [markdown]
# ### f string: (formated string)

# %%
Name = "Rupesh"
Age = 26
print(f"My Name is: {Name}, My age is: {Age}")
# Out:
# My Name is: Rupesh, My age is: 26

# %%
a = 45
b = 33
c = a + b
d = a - b
print(f"The addition is: {c}, The Substraction is: {d}")
# Out:
# The addition is: 78, The Substraction is: 12

# %% [markdown]
# ### islower() :- checks weather all the case is lower.

# %%
print(help(str.islower))
# Out:
# Help on method_descriptor:
#
# islower(self, /) unbound builtins.str method
#     Return True if the string is a lowercase string, False otherwise.
#
#     A string is lowercase if all cased characters in the string are lowercase and
#     there is at least one cased character in the string.
#
# None

# %%
a = "programming"

# %%
a.islower()
# Out:
# True

# %%
a = "PROGRAMMING"
a.islower()
# Out:
# False

# %% [markdown]
# ### isupper(): checks weather all case is Upper.

# %%
print(help(str.isupper))
# Out:
# Help on method_descriptor:
#
# isupper(self, /) unbound builtins.str method
#     Return True if the string is an uppercase string, False otherwise.
#
#     A string is uppercase if all cased characters in the string are uppercase and
#     there is at least one cased character in the string.
#
# None

# %%
a = "PROGRAMMING"
a.isupper()
# Out:
# True

# %%
a = "PRogRamMinG"
a.isupper()
# Out:
# False

# %% [markdown]
# ### isdigit() : check if all characters are digits.

# %%
a = '123'
a
# Out:
# '123'

# %%
a.isdigit()
# Out:
# True

# %%
a = 'Python456'
a.isdigit()
# Out:
# False

# %% [markdown]
# ### isalpha() : checks if all the characters are alphabhets

# %%
a = 'programming'
a.isalpha()
# Out:
# True

# %%
a = 'PRogrAmMing'
a.isalpha()
# Out:
# True

# %%
a = 'programming456'
a.isalpha()
# Out:
# False

# %% [markdown]
# ### isalnum() : checks all character having alphabets and numberics

# %%
a = "Programming"
a.isalnum()
# Out:
# True

# %%
a = "python456"
a.isalnum()
# Out:
# True

# %%
a= "python_programming"  # (_) does not belongs to alphabets or either numberics, it is a special character.
a.isalnum()
# Out:
# False

# %% [markdown]
# ### isspace() : Return True is the string is White space string.

# %%
print(help(str.isspace))
# Out:
# Help on method_descriptor:
#
# isspace(self, /) unbound builtins.str method
#     Return True if the string is a whitespace string, False otherwise.
#
#     A string is whitespace if all characters in the string are whitespace and there
#     is at least one character in the string.
#
# None

# %%
a = '    '
a.isspace()
# Out:
# True

# %%
a = ' '
a.isspace()
# Out:
# True

# %% [markdown]
# ### istitle() : returns True is the give string is Title Case.

# %%
a = "Python Programming Language"
a.istitle()
# Out:
# True

# %%
a = "python programming language"
a.istitle()
# Out:
# False

# %%
a.title()
# Out:
# 'Python Programming Language'

# %% [markdown]
# ### Strip() : remove Leading & Trailing white spaces
# - Leading white space : Starting white space (spaces on the left side)
# - Trailing white space : Ending white space (spaces on the right side)

# %%
a = '      Programming           '
a.strip()
# Out:
# 'Programming'

# %%
a = '        python'
a.strip()
# Out:
# 'python'

# %% [markdown]
# ### lstrip(): remove only Leading white space (left side)`

# %%
a = '         Rupesh'
a.lstrip()
# Out:
# 'Rupesh'

# %%
a = '        Tamaturi           '
a.lstrip()
# Out:
# 'Tamaturi           '

# %% [markdown]
# ### rstip() : remove only Trailing white spaces (right side)

# %%
a = 'RUPESH_TAMATURI            '
a.rstrip()
# Out:
# 'RUPESH_TAMATURI'

# %%
a = '        RUPESH_TAMATURI         '
a.rstrip()
# Out:
# '        RUPESH_TAMATURI'

# %% [markdown]
# ### center() :-

# %%
a = "python"

# %%
a.center(16)
# Out:
# '     python     '

# %%
a.center(14,'/')
# Out:
# '////python////'

# %%
a.center(14,'*')
# Out:
# '****python****'

# %%
a.center(11,'*')
# Out:
# '***python**'

# %% [markdown]
# ### replace() :

# %%
a = 'programming'
a.replace('p','j')
# Out:
# 'jrogramming'

# %%
a = 'python'
a.replace('p','c')
# Out:
# 'cython'

# %%
a = "python is good , python is popular , python is easy"

# %%
a.replace('python','java')
# Out:
# 'java is good , java is popular , java is easy'

# %%
a.replace('python','java',2)
# Out:
# 'java is good , java is popular , python is easy'

# %%
a.replace('python','java')
# Out:
# 'java is good , java is popular , java is easy'

# %%
a.replace('python',' ')
# Out:
# '  is good ,   is popular ,   is easy'

# %% [markdown]
# ### isidentifier()

# %%
print(help(str.isidentifier))
# Out:
# Help on method_descriptor:
#
# isidentifier(self, /) unbound builtins.str method
#     Return True if the string is a valid Python identifier, False otherwise.
#
#     Call keyword.iskeyword(s) to test whether string s is a reserved identifier,
#     such as "def" or "class".
#
# None

# %%
a = '4area'

# %%
a.isidentifier()
# Out:
# False

# %%
a = '_area'       #identfiers should only start with word of special charac (_) only
a.isidentifier()
# Out:
# True

# %%
a ='if'  # 'If' is a keyword, but in name it takes as identifier, to check if its keyword use 'keyword.iskeyword()'
a.isidentifier()
# Out:
# True

# %%
import keyword

# %%
keyword.iskeyword('if')
# Out:
# True

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(keyword.kwlist))
# Out:
# 35
